# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import LinearRegression

# %%
dados = pd.read_csv('Wine.csv')
dados = dados[["Alcohol", "Magnesium", "Customer_Segment"]]

dados.head()
# Out:
#    Alcohol  Magnesium  Customer_Segment
# 0    14.23        127                 1
# 1    13.20        100                 1
# 2    13.16        101                 1
# 3    14.37        113                 1
# 4    13.24        118                 1

# %%
x = dados.drop(columns="Customer_Segment")
y = dados.Customer_Segment

np.random.seed(42)
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size=0.2)

# %%
class Processt(BaseEstimator, TransformerMixin):
    def __init__(self, feature_name):
        print("\n>>>>init() called\n")
        self.feature_name = feature_name
        
    def fit(self, x, y=None):
        print("\n>>>>fit() called\n")
        return self
        
    def transform(self, x, y=None):
        print("\n>>>>transform() called\n")
        x_ = x.copy()
        x_["nova"] = x_[self.feature_name] ** 2
        print(x_)
        return x_

# %%
process = Processt("Magnesium")
process.fit(treino_x, treino_y)
process.transform(treino_x, treino_y)
# Out:
# >>>>init() called
#
#
# >>>>fit() called
#
#
# >>>>transform() called
#
#      Alcohol  Magnesium   nova
# 158    14.34         98   9604
# 137    12.53         96   9216
# 98     12.37         88   7744
# 159    13.48         89   7921
# 38     13.07         98   9604
# ..       ...        ...    ...
# 71     13.86         86   7396
# 106    12.25         80   6400
# 14     14.38        102  10404
# 92     12.69         80   6400
# 102    12.34         98   9604
#
# [142 rows x 3 columns]
#      Alcohol  Magnesium   nova
# 158    14.34         98   9604
# 137    12.53         96   9216
# 98     12.37         88   7744
# 159    13.48         89   7921
# 38     13.07         98   9604
# ..       ...        ...    ...
# 71     13.86         86   7396
# 106    12.25         80   6400
# 14     14.38        102  10404
# 92     12.69         80   6400
# 102    12.34         98   9604
#
# [142 rows x 3 columns]

# %%
pipeline = Pipeline(steps=[('teste', Processt("Magnesium")),
                           ('model', LinearRegression())
                          ])

pipeline.fit(treino_x, treino_y)
pipeline.predict(teste_x)
# Out:
# >>>>init() called
#
#
# >>>>fit() called
#
#
# >>>>transform() called
#
#      Alcohol  Magnesium   nova
# 158    14.34         98   9604
# 137    12.53         96   9216
# 98     12.37         88   7744
# 159    13.48         89   7921
# 38     13.07         98   9604
# ..       ...        ...    ...
# 71     13.86         86   7396
# 106    12.25         80   6400
# 14     14.38        102  10404
# 92     12.69         80   6400
# 102    12.34         98   9604
#
# [142 rows x 3 columns]
#
# >>>>transform() called
#
#      Alcohol  Magnesium   nova
# 19     13.64        116  13456
# 45     14.21        111  12321
# 140    12.93         96   9216
# 30     13.73        101  10201
# 67     12.37         78   6084
# 16     14.30        120  14400
# 119    12.00         87   7569
# 174    13.40        102  10404
# 109    11.61         94   8836
# 141    13.36         89   7921
# 24     13.50         96   9216
# 150    13.50        123  15129
# 41     13.41         90   8100
# ...
